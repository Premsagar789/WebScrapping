# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup

import re
import time

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
url = "https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1"

# %%
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
pagecontent= page.text

# %%
page.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
soup = BeautifulSoup(pagecontent)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links = soup.find_all("div" ,attrs = {'class':'_30jeq3 _1_WHN1'})

# %%
links
# Out:
# [<div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹5,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹4,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹72,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹22,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹5,499</div>,
# ...

# %%
links[0]
# Out:
# <div class="_30jeq3 _1_WHN1">₹11,999</div>

# %%
links[0].text
# Out:
# '₹11,999'

# %%
for links in links:
    print(links.text, end= " | ")
# Out:
# ₹11,999 | ₹11,999 | ₹5,499 | ₹4,999 | ₹14,999 | ₹12,999 | ₹12,999 | ₹12,999 | ₹13,999 | ₹14,999 | ₹11,999 | ₹11,999 | ₹11,999 | ₹10,999 | ₹10,999 | ₹14,999 | ₹13,999 | ₹72,999 | ₹22,999 | ₹10,999 | ₹5,499 | ₹15,999 | ₹22,999 | ₹9,999 |

# %%
#_4rR01T
links_id = soup.find_all("div" ,{'class':'_4rR01T'})
for links_id in links_id:
    print(links_id.text)
    print()
# Out:
# Motorola G34 5G (Charcoal Black, 128 GB)
#
# Motorola G34 5G (Ocean Green, 128 GB)
#
# POCO C51 (Royal Blue, 64 GB)
#
# POCO C51 - Locked with Airtel Prepaid (Royal Blue, 64 GB)
#
# vivo T2x 5G (Aurora Gold, 128 GB)
#
# vivo T2x 5G (Marine Blue, 128 GB)
#
# vivo T2x 5G (Glimmer Black, 128 GB)
#
# vivo T2x 5G (Aurora Gold, 128 GB)
#
# Motorola g54 5G (Pearl Blue, 128 GB)
#
# vivo T2x 5G (Marine Blue, 128 GB)
#
# vivo T2x 5G (Aurora Gold, 128 GB)
#
# vivo T2x 5G (Glimmer Black, 128 GB)
#
# vivo T2x 5G (Marine Blue, 128 GB)
#
# Motorola G34 5G (Ocean Green, 128 GB)
#
# Motorola G34 5G (Ice Blue, 128 GB)
#
# vivo T2x 5G (Glimmer Black, 128 GB)
#
# Motorola g54 5G (Midnight Blue, 128 GB)
#
# Apple iPhone 15 (Blue, 128 GB)
#
# Motorola Edge 40 Neo (Caneel Bay, 128 GB)
#
# Motorola G34 5G (Charcoal Black, 128 GB)
#
# POCO C51 (Power Black, 64 GB)
#
# Motorola g54 5G (Mint Green, 256 GB)
#
# Motorola Edge 40 Neo (Soothing Sea, 128 GB)
#
# POCO M6 5G (Orion Blue, 128 GB)

# %%
product_name =[]
price =[]
rating =[]
features =[]
discount=[]
pagenum =[]


for i in range(1,50):
    url= "https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}".format(i)
    page= requests.get(url)
    pagecontent= page.text
    soup= BeautifulSoup(pagecontent)
    


    for x in soup.find_all('div',attrs={'class':'_3pLy-c row'}):
        pname= x.find('div',attrs={'class':'_4rR01T'})
        cost=  x.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
        rat=   x.find('div',attrs={'class':'_3LWZlK'})
        spec=  x.find('div',attrs={'class':'fMghEO'})
        dis=   x.find('div',attrs={'class':'_3Ay6Sb'})
        
        
        if pname is None:
            product_name.append(np.NaN)
            
        else:
            product_name.append(pname.text)
            
        if cost is None:
            price.append(np.NaN)
            
        else:
            price.append(cost.text)
            
            
        if rat is None:
            rating.append(np.NaN)
            
        else:
            rating.append(rat.text)
            
            
        if spec is None:
            features.append(np.NaN)
            
        else:
            features.append(spec.text)
            
        if dis is None:
            discount.append(np.NaN)
            
        else:
            discount.append(dis.text)
            
            
        pagenum.append(i)

# %%
for l in [product_name, price, rating, features,discount,pagenum]:
    print(len(l))
# Out:
# 984
# 984
# 984
# 984
# 984
# 984

# %%
mobiles_df= pd.DataFrame({'ProductName':product_name, 'Price':price, 'Rating':rating, 'Features':features,'Discount':discount,'PageNo':pagenum})

# %%
mobiles_df
# Out:
#                                            ProductName      Price Rating  \
# 0             Motorola G34 5G (Charcoal Black, 128 GB)    ₹11,999    4.2
# 1                Motorola G34 5G (Ocean Green, 128 GB)    ₹11,999    4.2
# 2                         POCO C51 (Royal Blue, 64 GB)     ₹5,499      4
# 3    POCO C51 - Locked with Airtel Prepaid (Royal B...     ₹4,999      4
# 4                    vivo T2x 5G (Aurora Gold, 128 GB)    ₹14,999    4.3
# ..                                                 ...        ...    ...
# 979  itel Muzik 110| 1900 mAh battery| Expandable S...     ₹1,199    4.1
# 980                  IQOO Z6 44W (Lumina Blue, 128 GB)    ₹13,499    4.2
# 981            SAMSUNG Galaxy A03 Core (Bronze, 32 GB)     ₹6,995    4.1
# 982       Apple iPhone 15 Pro (Black Titanium, 512 GB)  ₹1,61,990    4.7
# 983  Nokia 3310 Dual SIM Keypad Mobile with MP3 Pla...     ₹3,899    3.9
#
#                                               Features Discount  PageNo
# ...

# %%
mobiles_df["Features"][0]
# Out:
# '8 GB RAM | 128 GB ROM16.51 cm (6.5 inch) HD+ Display50MP + 2MP | 16MP Front Camera5000 mAh BatterySnapdragon 695 5G Processor1 Year on Handset and 6 Months on Accessories'

# %%
storage_regex= "^\[0-9] GB ROM|[0-9]* GB RAM+"
re.findall(storage_regex,mobiles_df["Features"][0])
# Out:
# ['8 GB RAM']

# %%
" ".join(re.findall(storage_regex,mobiles_df["Features"][0]))
# Out:
# '8 GB RAM'

# %%
mobiles_df["RAM"]= mobiles_df["Features"].apply(lambda x:" ".join(re.findall(storage_regex,x)))

# %%
mobiles_df
# Out:
#                                            ProductName     Price Rating  \
# 0             Motorola G34 5G (Charcoal Black, 128 GB)   11999.0    4.2
# 1                Motorola G34 5G (Ocean Green, 128 GB)   11999.0    4.2
# 2                         POCO C51 (Royal Blue, 64 GB)    5499.0      4
# 3    POCO C51 - Locked with Airtel Prepaid (Royal B...    4999.0      4
# 4                    vivo T2x 5G (Aurora Gold, 128 GB)   14999.0    4.3
# ..                                                 ...       ...    ...
# 979  itel Muzik 110| 1900 mAh battery| Expandable S...    1199.0    4.1
# 980                  IQOO Z6 44W (Lumina Blue, 128 GB)   13499.0    4.2
# 981            SAMSUNG Galaxy A03 Core (Bronze, 32 GB)    6995.0    4.1
# 982       Apple iPhone 15 Pro (Black Titanium, 512 GB)  161990.0    4.7
# 983  Nokia 3310 Dual SIM Keypad Mobile with MP3 Pla...    3899.0    3.9
#
#                                               Features Discount  PageNo  \
# ...

# %%
mobiles_df["Brand"] =mobiles_df["ProductName"].apply(lambda x: " ".join(re.findall("^\w+",x)))
mobiles_df
# Out:
#                                            ProductName     Price Rating  \
# 0             Motorola G34 5G (Charcoal Black, 128 GB)   11999.0    4.2
# 1                Motorola G34 5G (Ocean Green, 128 GB)   11999.0    4.2
# 2                         POCO C51 (Royal Blue, 64 GB)    5499.0      4
# 3    POCO C51 - Locked with Airtel Prepaid (Royal B...    4999.0      4
# 4                    vivo T2x 5G (Aurora Gold, 128 GB)   14999.0    4.3
# ..                                                 ...       ...    ...
# 979  itel Muzik 110| 1900 mAh battery| Expandable S...    1199.0    4.1
# 980                  IQOO Z6 44W (Lumina Blue, 128 GB)   13499.0    4.2
# 981            SAMSUNG Galaxy A03 Core (Bronze, 32 GB)    6995.0    4.1
# 982       Apple iPhone 15 Pro (Black Titanium, 512 GB)  161990.0    4.7
# 983  Nokia 3310 Dual SIM Keypad Mobile with MP3 Pla...    3899.0    3.9
#
#                                               Features Discount  PageNo  \
# ...

# %%
mobiles_df["Price"]=mobiles_df["Price"].apply(lambda x: str(x).replace('₹','').replace(',','')).astype(float)

# %%
mobiles_df
# Out:
#                                            ProductName     Price Rating  \
# 0             Motorola G34 5G (Charcoal Black, 128 GB)   11999.0    4.2
# 1                Motorola G34 5G (Ocean Green, 128 GB)   11999.0    4.2
# 2                         POCO C51 (Royal Blue, 64 GB)    5499.0      4
# 3    POCO C51 - Locked with Airtel Prepaid (Royal B...    4999.0      4
# 4                    vivo T2x 5G (Aurora Gold, 128 GB)   14999.0    4.3
# ..                                                 ...       ...    ...
# 979  itel Muzik 110| 1900 mAh battery| Expandable S...    1199.0    4.1
# 980                  IQOO Z6 44W (Lumina Blue, 128 GB)   13499.0    4.2
# 981            SAMSUNG Galaxy A03 Core (Bronze, 32 GB)    6995.0    4.1
# 982       Apple iPhone 15 Pro (Black Titanium, 512 GB)  161990.0    4.7
# 983  Nokia 3310 Dual SIM Keypad Mobile with MP3 Pla...    3899.0    3.9
#
#                                               Features Discount  PageNo  \
# ...

# %%
mobiles_df["Brand"] =mobiles_df["ProductName"].apply(lambda x: " ".join(re.findall("^\w+",x)))
mobiles_df
# Out:
#                                            ProductName     Price Rating  \
# 0             Motorola G34 5G (Charcoal Black, 128 GB)   11999.0    4.2
# 1                Motorola G34 5G (Ocean Green, 128 GB)   11999.0    4.2
# 2                         POCO C51 (Royal Blue, 64 GB)    5499.0      4
# 3    POCO C51 - Locked with Airtel Prepaid (Royal B...    4999.0      4
# 4                    vivo T2x 5G (Aurora Gold, 128 GB)   14999.0    4.3
# ..                                                 ...       ...    ...
# 979  itel Muzik 110| 1900 mAh battery| Expandable S...    1199.0    4.1
# 980                  IQOO Z6 44W (Lumina Blue, 128 GB)   13499.0    4.2
# 981            SAMSUNG Galaxy A03 Core (Bronze, 32 GB)    6995.0    4.1
# 982       Apple iPhone 15 Pro (Black Titanium, 512 GB)  161990.0    4.7
# 983  Nokia 3310 Dual SIM Keypad Mobile with MP3 Pla...    3899.0    3.9
#
#                                               Features Discount  PageNo  \
# ...

# %%
#drop unrelated/blank columns
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
storage_regex= "^\[0-9] GB RAM|[0-9]* GB ROM+"
re.findall(storage_regex,mobiles_df["Features"][0])
# Out:
# ['128 GB ROM']

# %%
" ".join(re.findall(storage_regex,mobiles_df["Features"][0]))
# Out:
# '128 GB ROM'

# %%
mobiles_df["ROM"]= mobiles_df["Features"].apply(lambda x:" ".join(re.findall(storage_regex,x)))

# %%
mobiles_df
# Out:
#                                            ProductName     Price Rating  \
# 0             Motorola G34 5G (Charcoal Black, 128 GB)   11999.0    4.2
# 1                Motorola G34 5G (Ocean Green, 128 GB)   11999.0    4.2
# 2                         POCO C51 (Royal Blue, 64 GB)    5499.0      4
# 3    POCO C51 - Locked with Airtel Prepaid (Royal B...    4999.0      4
# 4                    vivo T2x 5G (Aurora Gold, 128 GB)   14999.0    4.3
# ..                                                 ...       ...    ...
# 979  itel Muzik 110| 1900 mAh battery| Expandable S...    1199.0    4.1
# 980                  IQOO Z6 44W (Lumina Blue, 128 GB)   13499.0    4.2
# 981            SAMSUNG Galaxy A03 Core (Bronze, 32 GB)    6995.0    4.1
# 982       Apple iPhone 15 Pro (Black Titanium, 512 GB)  161990.0    4.7
# 983  Nokia 3310 Dual SIM Keypad Mobile with MP3 Pla...    3899.0    3.9
#
#                                               Features Discount  PageNo  \
# ...

# %%
#drop unrelated/blank columns
mobiles_df.drop(['Brand'], axis=1, inplace=True)

# %%
mobiles_df
# Out:
#                                            ProductName     Price Rating  \
# 0             Motorola G34 5G (Charcoal Black, 128 GB)   11999.0    4.2
# 1                Motorola G34 5G (Ocean Green, 128 GB)   11999.0    4.2
# 2                         POCO C51 (Royal Blue, 64 GB)    5499.0      4
# 3    POCO C51 - Locked with Airtel Prepaid (Royal B...    4999.0      4
# 4                    vivo T2x 5G (Aurora Gold, 128 GB)   14999.0    4.3
# ..                                                 ...       ...    ...
# 979  itel Muzik 110| 1900 mAh battery| Expandable S...    1199.0    4.1
# 980                  IQOO Z6 44W (Lumina Blue, 128 GB)   13499.0    4.2
# 981            SAMSUNG Galaxy A03 Core (Bronze, 32 GB)    6995.0    4.1
# 982       Apple iPhone 15 Pro (Black Titanium, 512 GB)  161990.0    4.7
# 983  Nokia 3310 Dual SIM Keypad Mobile with MP3 Pla...    3899.0    3.9
#
#                                               Features Discount  PageNo  \
# ...

# %%
mobiles_df["Brand"] =mobiles_df["ProductName"].apply(lambda x: " ".join(re.findall("^\w+",x)))
mobiles_df
# Out:
#                                            ProductName     Price Rating  \
# 0             Motorola G34 5G (Charcoal Black, 128 GB)   11999.0    4.2
# 1                Motorola G34 5G (Ocean Green, 128 GB)   11999.0    4.2
# 2                         POCO C51 (Royal Blue, 64 GB)    5499.0      4
# 3    POCO C51 - Locked with Airtel Prepaid (Royal B...    4999.0      4
# 4                    vivo T2x 5G (Aurora Gold, 128 GB)   14999.0    4.3
# ..                                                 ...       ...    ...
# 979  itel Muzik 110| 1900 mAh battery| Expandable S...    1199.0    4.1
# 980                  IQOO Z6 44W (Lumina Blue, 128 GB)   13499.0    4.2
# 981            SAMSUNG Galaxy A03 Core (Bronze, 32 GB)    6995.0    4.1
# 982       Apple iPhone 15 Pro (Black Titanium, 512 GB)  161990.0    4.7
# 983  Nokia 3310 Dual SIM Keypad Mobile with MP3 Pla...    3899.0    3.9
#
#                                               Features Discount  PageNo  \
# ...

# %%
mobiles_df
# Out:
#                                            ProductName     Price Rating  \
# 0             Motorola G34 5G (Charcoal Black, 128 GB)   11999.0    4.2
# 1                Motorola G34 5G (Ocean Green, 128 GB)   11999.0    4.2
# 2                         POCO C51 (Royal Blue, 64 GB)    5499.0      4
# 3    POCO C51 - Locked with Airtel Prepaid (Royal B...    4999.0      4
# 4                    vivo T2x 5G (Aurora Gold, 128 GB)   14999.0    4.3
# ..                                                 ...       ...    ...
# 979  itel Muzik 110| 1900 mAh battery| Expandable S...    1199.0    4.1
# 980                  IQOO Z6 44W (Lumina Blue, 128 GB)   13499.0    4.2
# 981            SAMSUNG Galaxy A03 Core (Bronze, 32 GB)    6995.0    4.1
# 982       Apple iPhone 15 Pro (Black Titanium, 512 GB)  161990.0    4.7
# 983  Nokia 3310 Dual SIM Keypad Mobile with MP3 Pla...    3899.0    3.9
#
#                                               Features Discount  PageNo  \
# ...

# %%
mobiles_df["Price"]=mobiles_df["Price"].apply(lambda x: str(x).replace('%','').replace('off','')).astype(float)

# %%
mobiles_df
# Out:
#                                            ProductName     Price Rating  \
# 0             Motorola G34 5G (Charcoal Black, 128 GB)   11999.0    4.2
# 1                Motorola G34 5G (Ocean Green, 128 GB)   11999.0    4.2
# 2                         POCO C51 (Royal Blue, 64 GB)    5499.0      4
# 3    POCO C51 - Locked with Airtel Prepaid (Royal B...    4999.0      4
# 4                    vivo T2x 5G (Aurora Gold, 128 GB)   14999.0    4.3
# ..                                                 ...       ...    ...
# 979  itel Muzik 110| 1900 mAh battery| Expandable S...    1199.0    4.1
# 980                  IQOO Z6 44W (Lumina Blue, 128 GB)   13499.0    4.2
# 981            SAMSUNG Galaxy A03 Core (Bronze, 32 GB)    6995.0    4.1
# 982       Apple iPhone 15 Pro (Black Titanium, 512 GB)  161990.0    4.7
# 983  Nokia 3310 Dual SIM Keypad Mobile with MP3 Pla...    3899.0    3.9
#
#                                               Features Discount  PageNo  \
# ...

# %% [markdown]
# ## Data vizulisation

# %%
plt.figure(figsize=(13,5))
sns.histplot(mobiles_df.Price)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(mobiles_df, x="Rating")
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
plt.figure(figsize=(13,5))
sns.scatterplot(data=mobiles_df,x=mobiles_df["Brand"],y=mobiles_df["Price"].head(10))
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(10,5))
mobiles_df.groupby('ProductName')['Price'].sum().head(10).sort_values(ascending=False).plot(kind='barh')
plt.xticks(rotation=35)
plt.show()
# Out:
# <Axes: ylabel='ProductName'>
# (array([     0.,  25000.,  50000.,  75000., 100000., 125000., 150000.,
#         175000., 200000., 225000.]),
#  [Text(0.0, 0, '0'),
#   Text(25000.0, 0, '25000'),
#   Text(50000.0, 0, '50000'),
#   Text(75000.0, 0, '75000'),
#   Text(100000.0, 0, '100000'),
#   Text(125000.0, 0, '125000'),
#   Text(150000.0, 0, '150000'),
#   Text(175000.0, 0, '175000'),
#   Text(200000.0, 0, '200000'),
#   Text(225000.0, 0, '225000')])

# %%
# Plot the top order priority in a histogram
plt.figure(figsize=(10, 5))
sns.histplot(mobiles_df['Brand'].head(10), color='#b80045')
plt.xlabel('Brand')
plt.ylabel('Price')
plt.title('Top sold Products')
plt.show()
# Out:
# <Axes: xlabel='Brand', ylabel='Count'>
# Text(0.5, 0, 'Brand')
# Text(0, 0.5, 'Price')
# Text(0.5, 1.0, 'Top sold Products')

# %%
sns.countplot(mobiles_df, x="Brand")
# Out:
# <Axes: xlabel='Brand', ylabel='count'>
